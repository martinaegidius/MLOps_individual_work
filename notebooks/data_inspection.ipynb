# %%
import torch 
import matplotlib.pyplot as plt 


data_dir = "data/corruptmnist_v1/"
sample = "train_images_0.pt"

f = data_dir+sample

images = torch.load(f)

# %%
print(images.shape)

for i in range(10):
    im = images[i,:,:].squeeze().numpy()
    plt.figure()
    plt.imshow(im)
# Out:
# torch.Size([5000, 28, 28])

# %%
images.shape
# Out:
# torch.Size([5000, 28, 28])

# %% [markdown]
# They seem to be corrupted by noise (smoothing noise)

# %%
import torch.nn as nn 

m = nn.MaxPool2d(2, stride=2)
input = torch.randn(10,1, 28, 28)
output = m(input)
print(output.shape)
# Out:
# torch.Size([10, 1, 14, 14])

# %%
conv1 = nn.Conv2d(in_channels=1,out_channels=4,kernel_size=3,stride=1,bias=True)
conv2 = nn.Conv2d(in_channels=4,out_channels = 32,kernel_size=3,stride=1,bias=True)
conv3 = nn.Conv2d(in_channels=32,out_channels = 64,kernel_size=3,stride=1,bias=True)

conv3(m(conv2(m(conv1(input))))).shape
# Out:
# torch.Size([10, 64, 3, 3])

# %%
64*3*3
# Out:
# 576
